# %%
from google.colab import drive
drive.mount('/content/gdrive')

import sys
sys.path.append('/content/gdrive/My Drive/COSC440_DeepLearning/assignment2')

from importlib import reload

# Install TensorFlow
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass
# Out:
# Mounted at /content/gdrive
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.

# %%
import assignment
from importlib import reload
import unittest

# %%
# Run Tests
import assignment_tests
import convolution
reload(convolution)
reload(assignment_tests)
reload(assignment)
unittest.main(module='assignment_tests', argv=[''], exit=False)
# Out:
# .....
# ----------------------------------------------------------------------
# Ran 5 tests in 0.310s
#
# OK

# %%
# Test Preprocessing
import preprocess
reload(preprocess)
inputs, labels = preprocess.get_data('/content/gdrive/MyDrive/COSC440_DeepLearning/assignment2/CIFAR_data/train',3,5)
inputs.shape, labels.shape
# Out:
# ((10000, 32, 32, 3), TensorShape([10000, 2]))

# %%
# Test convolution
import numpy as np
import convolution
reload(convolution)
filters = np.ones((3,3,3,1))
inputs_conv = convolution.conv2d(inputs, filters, [1,1,1,1], "SAME")
inputs_conv.shape
# Out:
# TensorShape([10000, 32, 32, 1])

# %%
# Run Main
reload(assignment)
assignment.main('/content/gdrive/MyDrive/COSC440_DeepLearning/assignment2/CIFAR_data/')
# Out:
# Training ModelPart3
# Accuracy on training set after 1 Epochs: 0.609000027179718
# Accuracy on training set after 2 Epochs: 0.6503000259399414
# Accuracy on training set after 3 Epochs: 0.6823999881744385
# Accuracy on training set after 4 Epochs: 0.7013999819755554
# Accuracy on training set after 5 Epochs: 0.7060999870300293
# Accuracy on training set after 6 Epochs: 0.7368999719619751
# Accuracy on training set after 7 Epochs: 0.7434999942779541
# Accuracy on training set after 8 Epochs: 0.753000020980835
# Accuracy on training set after 9 Epochs: 0.7544999718666077
# Accuracy on training set after 10 Epochs: 0.758899986743927
# Accuracy on training set after 11 Epochs: 0.7559999823570251
# Accuracy on training set after 12 Epochs: 0.7771999835968018
# Accuracy on training set after 13 Epochs: 0.7774999737739563
# Accuracy on training set after 14 Epochs: 0.7746999859809875
# Accuracy on training set after 15 Epochs: 0.7861999869346619
# ...
