# %% [markdown]
# # Setup

# %%
from google.colab import drive
drive.mount('/content/gdrive')

import sys
sys.path.append('/content/gdrive/My Drive/COSC440_DeepLearning/assignment1')

import assignment
from importlib import reload

import unittest
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # Run Assignment 1

# %%
#reload allows "hotcode" swapping so the python runtime doesn't need restart
reload(assignment)
assignment.main("/content/gdrive/My Drive/COSC440_DeepLearning/assignment1/MNIST_data/")
# Out:
# Read 60000 data points, shape: (60000, 784), data: [[0. 0. 0. ... 0. 0. 0.], ...]
# Read 60000 labels, shape: (60000,), labels: [5 0 4 ... 5 6 8]
# Read 10000 data points, shape: (10000, 784), data: [[0. 0. 0. ... 0. 0. 0.], ...]
# Read 10000 labels, shape: (10000,), labels: [7 2 1 ... 4 5 6]
# Training with batch size 100 and 60000 data inputs started...
# Training finished...
# The accuracy is 85.98%
# end of assignment 1

# %%
import assignment_tests
reload(assignment_tests)
reload(assignment)
unittest.main(module='assignment_tests', argv=[''], exit=False)
# Out:
# ...
# ----------------------------------------------------------------------
# Ran 3 tests in 0.019s
#
# OK
